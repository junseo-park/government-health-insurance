# %% [markdown]
# # Cleaning the Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
educ_exp = pd.read_csv('data/raw_data/education_expenditure/API_SE.XPD.TOTL.GD.ZS_DS2_en_csv_v2.csv', header=2)
educ_exp.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1  Afghanistan          AFG
# 2       Angola          AGO
# 3      Albania          ALB
# 4      Andorra          AND
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Government expenditure on education, total (% ...  SE.XPD.TOTL.GD.ZS   NaN
# 1  Government expenditure on education, total (% ...  SE.XPD.TOTL.GD.ZS   NaN
# 2  Government expenditure on education, total (% ...  SE.XPD.TOTL.GD.ZS   NaN
# 3  Government expenditure on education, total (% ...  SE.XPD.TOTL.GD.ZS   NaN
# 4  Government expenditure on education, total (% ...  SE.XPD.TOTL.GD.ZS   NaN
#
#    1961  1962  1963  1964  1965     ...          2008     2009     2010  \
# 0   NaN   NaN   NaN   NaN   NaN     ...       4.91559  5.92467  6.71249
# 1   NaN   NaN   NaN   NaN   NaN     ...           NaN      NaN  3.46196
# 2   NaN   NaN   NaN   NaN   NaN     ...           NaN      NaN  3.47644
# 3   NaN   NaN   NaN   NaN   NaN     ...           NaN      NaN      NaN
# 4   NaN   NaN   NaN   NaN   NaN     ...       2.93457  3.16387  3.06580
#
#       2011     2012     2013     2014     2015  2016  Unnamed: 61
# 0  6.03687  6.55339  6.79629  6.13062      NaN   NaN          NaN
# 1  3.43785  2.52441  3.47171  3.77759  3.37581   NaN          NaN
# 2      NaN      NaN      NaN      NaN      NaN   NaN          NaN
# 3      NaN      NaN  3.53798      NaN      NaN   NaN          NaN
# 4  3.15889      NaN  2.46258  3.06442      NaN   NaN          NaN
#
# [5 rows x 62 columns]

# %%
print('educ_exp has', educ_exp.shape[0], 'rows and', educ_exp.shape[1], 'columns.')
# Out:
# educ_exp has 264 rows and 62 columns.

# %%
print('There are', len(educ_exp['Country Name'].unique()), 'unique countries:')
print(educ_exp['Country Name'].unique())
# Out:
# There are 264 unique countries:
# ['Aruba' 'Afghanistan' 'Angola' 'Albania' 'Andorra' 'Arab World'
#  'United Arab Emirates' 'Argentina' 'Armenia' 'American Samoa'
#  'Antigua and Barbuda' 'Australia' 'Austria' 'Azerbaijan' 'Burundi'
#  'Belgium' 'Benin' 'Burkina Faso' 'Bangladesh' 'Bulgaria' 'Bahrain'
#  'Bahamas, The' 'Bosnia and Herzegovina' 'Belarus' 'Belize' 'Bermuda'
#  'Bolivia' 'Brazil' 'Barbados' 'Brunei Darussalam' 'Bhutan' 'Botswana'
#  'Central African Republic' 'Canada' 'Central Europe and the Baltics'
#  'Switzerland' 'Channel Islands' 'Chile' 'China' "Cote d'Ivoire"
#  'Cameroon' 'Congo, Dem. Rep.' 'Congo, Rep.' 'Colombia' 'Comoros'
#  'Cabo Verde' 'Costa Rica' 'Caribbean small states' 'Cuba' 'Curacao'
#  'Cayman Islands' 'Cyprus' 'Czech Republic' 'Germany' 'Djibouti'
#  'Dominica' 'Denmark' 'Dominican Republic' 'Algeria'
#  'East Asia & Pacific (excluding high income)'
#  'Early-demographic dividend' 'East Asia & Pacific'
#  'Europe & Central Asia (excluding high income)' 'Europe & Central Asia'
#  'Ecuador' 'Egypt, Arab Rep.' 'Euro area' 'Eritrea' 'Spain' 'Estonia'
#  'Ethiopia' 'European Union' 'Fragile and conflict affected situations'
#  'Finland' 'Fiji' 'France' 'Faroe Islands' 'Micronesia, Fed. Sts.' 'Gabon'
#  'United Kingdom' 'Georgia' 'Ghana' 'Gibraltar' 'Guinea' 'Gambia, The'
#  'Guinea-Bissau' 'Equatorial Guinea' 'Greece' 'Grenada' 'Greenland'
#  'Guatemala' 'Guam' 'Guyana' 'High income' 'Hong Kong SAR, China'
#  'Honduras' 'Heavily indebted poor countries (HIPC)' 'Croatia' 'Haiti'
#  'Hungary' 'IBRD only' 'IDA & IBRD total' 'IDA total' 'IDA blend'
#  'Indonesia' 'IDA only' 'Isle of Man' 'India' 'Not classified' 'Ireland'
#  'Iran, Islamic Rep.' 'Iraq' 'Iceland' 'Israel' 'Italy' 'Jamaica' 'Jordan'
#  'Japan' 'Kazakhstan' 'Kenya' 'Kyrgyz Republic' 'Cambodia' 'Kiribati'
#  'St. Kitts and Nevis' 'Korea, Rep.' 'Kuwait'
#  'Latin America & Caribbean (excluding high income)' 'Lao PDR' 'Lebanon'
#  'Liberia' 'Libya' 'St. Lucia' 'Latin America & Caribbean'
#  'Least developed countries: UN classification' 'Low income'
#  'Liechtenstein' 'Sri Lanka' 'Lower middle income' 'Low & middle income'
#  'Lesotho' 'Late-demographic dividend' 'Lithuania' 'Luxembourg' 'Latvia'
#  'Macao SAR, China' 'St. Martin (French part)' 'Morocco' 'Monaco'
#  'Moldova' 'Madagascar' 'Maldives' 'Middle East & North Africa' 'Mexico'
#  'Marshall Islands' 'Middle income' 'Macedonia, FYR' 'Mali' 'Malta'
#  'Myanmar' 'Middle East & North Africa (excluding high income)'
#  'Montenegro' 'Mongolia' 'Northern Mariana Islands' 'Mozambique'
#  'Mauritania' 'Mauritius' 'Malawi' 'Malaysia' 'North America' 'Namibia'
#  'New Caledonia' 'Niger' 'Nigeria' 'Nicaragua' 'Netherlands' 'Norway'
#  'Nepal' 'Nauru' 'New Zealand' 'OECD members' 'Oman' 'Other small states'
#  'Pakistan' 'Panama' 'Peru' 'Philippines' 'Palau' 'Papua New Guinea'
#  'Poland' 'Pre-demographic dividend' 'Puerto Rico'
#  'Korea, Dem. People’s Rep.' 'Portugal' 'Paraguay' 'West Bank and Gaza'
#  'Pacific island small states' 'Post-demographic dividend'
#  'French Polynesia' 'Qatar' 'Romania' 'Russian Federation' 'Rwanda'
#  'South Asia' 'Saudi Arabia' 'Sudan' 'Senegal' 'Singapore'
#  'Solomon Islands' 'Sierra Leone' 'El Salvador' 'San Marino' 'Somalia'
#  'Serbia' 'Sub-Saharan Africa (excluding high income)' 'South Sudan'
#  'Sub-Saharan Africa' 'Small states' 'Sao Tome and Principe' 'Suriname'
#  'Slovak Republic' 'Slovenia' 'Sweden' 'Swaziland'
#  'Sint Maarten (Dutch part)' 'Seychelles' 'Syrian Arab Republic'
#  'Turks and Caicos Islands' 'Chad'
#  'East Asia & Pacific (IDA & IBRD countries)'
#  'Europe & Central Asia (IDA & IBRD countries)' 'Togo' 'Thailand'
#  'Tajikistan' 'Turkmenistan'
#  'Latin America & the Caribbean (IDA & IBRD countries)' 'Timor-Leste'
#  'Middle East & North Africa (IDA & IBRD countries)' 'Tonga'
#  'South Asia (IDA & IBRD)' 'Sub-Saharan Africa (IDA & IBRD countries)'
#  'Trinidad and Tobago' 'Tunisia' 'Turkey' 'Tuvalu' 'Tanzania' 'Uganda'
#  'Ukraine' 'Upper middle income' 'Uruguay' 'United States' 'Uzbekistan'
#  'St. Vincent and the Grenadines' 'Venezuela, RB' 'British Virgin Islands'
#  'Virgin Islands (U.S.)' 'Vietnam' 'Vanuatu' 'World' 'Samoa' 'Kosovo'
#  'Yemen, Rep.' 'South Africa' 'Zambia' 'Zimbabwe']

# %%
to_remove = ['Arab World', 'American Samoa', 'Bermuda',
'Central Europe and the Baltics', 'Channel Islands', 'Caribbean small states',
'Cayman Islands', 'East Asia & Pacific (excluding high income)',
'Early-demographic dividend', 'East Asia & Pacific',
'Europe & Central Asia (excluding high income)', 'Europe & Central Asia',
'Euro area', 'European Union', 'Fragile and conflict affected situations',
'Faroe Islands', 'Gibraltar', 'Greenland', 'Guam', 'High income',
'Heavily indebted poor countries (HIPC)', 'IBRD only', 'IDA & IBRD total',
'IDA total', 'IDA blend', 'IDA only', 'Isle of Man', 'Not classified',
'Latin America & Caribbean (excluding high income)',
'Latin America & Caribbean', 'Least developed countries: UN classification',
'Low income', 'Lower middle income', 'Low & middle income',
'Late-demographic dividend', 'St. Martin (French part)',
'Middle East & North Africa', 'Middle income',
'Middle East & North Africa (excluding high income)', 'Northern Mariana Islands',
'North America', 'New Caledonia', 'OECD members', 'Other small states',
'Pre-demographic dividend', 'Puerto Rico', 'West Bank and Gaza',
'Pacific island small states', 'Post-demographic dividend', 'French Polynesia',
'South Asia', 'Sub-Saharan Africa (excluding high income)', 'Sub-Saharan Africa',
'Small states', 'Turks and Caicos Islands',
'East Asia & Pacific (IDA & IBRD countries)',
'Europe & Central Asia (IDA & IBRD countries)',
'Latin America & the Caribbean (IDA & IBRD countries)',
'Middle East & North Africa (IDA & IBRD countries)', 'South Asia (IDA & IBRD)',
'Sub-Saharan Africa (IDA & IBRD countries)', 'Upper middle income',
'British Virgin Islands', 'Virgin Islands (U.S.)', 'World']

# %%
def delete_rows(df, rows_to_delete):
    for i in range(len(df)):
        if df.loc[i, 'Country Name'] in rows_to_delete:
            df.drop(i, inplace=True)

educ_exp = pd.read_csv('data/raw_data/education_expenditure/API_SE.XPD.TOTL.GD.ZS_DS2_en_csv_v2.csv', header=2)
delete_rows(educ_exp, to_remove)

educ_exp.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1  Afghanistan          AFG
# 2       Angola          AGO
# 3      Albania          ALB
# 4      Andorra          AND
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Government expenditure on education, total (% ...  SE.XPD.TOTL.GD.ZS   NaN
# 1  Government expenditure on education, total (% ...  SE.XPD.TOTL.GD.ZS   NaN
# 2  Government expenditure on education, total (% ...  SE.XPD.TOTL.GD.ZS   NaN
# 3  Government expenditure on education, total (% ...  SE.XPD.TOTL.GD.ZS   NaN
# 4  Government expenditure on education, total (% ...  SE.XPD.TOTL.GD.ZS   NaN
#
#    1961  1962  1963  1964  1965     ...          2008     2009     2010  \
# 0   NaN   NaN   NaN   NaN   NaN     ...       4.91559  5.92467  6.71249
# 1   NaN   NaN   NaN   NaN   NaN     ...           NaN      NaN  3.46196
# 2   NaN   NaN   NaN   NaN   NaN     ...           NaN      NaN  3.47644
# 3   NaN   NaN   NaN   NaN   NaN     ...           NaN      NaN      NaN
# 4   NaN   NaN   NaN   NaN   NaN     ...       2.93457  3.16387  3.06580
#
#       2011     2012     2013     2014     2015  2016  Unnamed: 61
# 0  6.03687  6.55339  6.79629  6.13062      NaN   NaN          NaN
# 1  3.43785  2.52441  3.47171  3.77759  3.37581   NaN          NaN
# 2      NaN      NaN      NaN      NaN      NaN   NaN          NaN
# 3      NaN      NaN  3.53798      NaN      NaN   NaN          NaN
# 4  3.15889      NaN  2.46258  3.06442      NaN   NaN          NaN
#
# [5 rows x 62 columns]

# %%
print('educ_exp has', educ_exp.shape[0], 'rows and', educ_exp.shape[1], 'columns.')
# Out:
# educ_exp has 199 rows and 62 columns.

# %%
educ_exp.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', 'Unnamed: 61'],
#       dtype='object')

# %%
for col_name in educ_exp.columns:
    print(col_name, 'has', sum(pd.isnull(educ_exp[col_name])), 'NaN values')
# Out:
# Country Name has 0 NaN values
# Country Code has 0 NaN values
# Indicator Name has 0 NaN values
# Indicator Code has 0 NaN values
# 1960 has 199 NaN values
# 1961 has 199 NaN values
# 1962 has 199 NaN values
# 1963 has 199 NaN values
# 1964 has 199 NaN values
# 1965 has 199 NaN values
# 1966 has 199 NaN values
# 1967 has 199 NaN values
# 1968 has 199 NaN values
# 1969 has 199 NaN values
# 1970 has 171 NaN values
# 1971 has 152 NaN values
# 1972 has 155 NaN values
# 1973 has 153 NaN values
# 1974 has 154 NaN values
# 1975 has 147 NaN values
# 1976 has 152 NaN values
# 1977 has 152 NaN values
# 1978 has 152 NaN values
# 1979 has 144 NaN values
# 1980 has 135 NaN values
# 1981 has 143 NaN values
# 1982 has 139 NaN values
# 1983 has 145 NaN values
# 1984 has 142 NaN values
# 1985 has 146 NaN values
# 1986 has 139 NaN values
# 1987 has 145 NaN values
# 1988 has 145 NaN values
# 1989 has 143 NaN values
# 1990 has 148 NaN values
# 1991 has 146 NaN values
# 1992 has 143 NaN values
# 1993 has 142 NaN values
# 1994 has 129 NaN values
# 1995 has 118 NaN values
# 1996 has 119 NaN values
# 1997 has 162 NaN values
# 1998 has 110 NaN values
# 1999 has 80 NaN values
# 2000 has 78 NaN values
# 2001 has 82 NaN values
# 2002 has 73 NaN values
# 2003 has 87 NaN values
# 2004 has 75 NaN values
# 2005 has 88 NaN values
# 2006 has 87 NaN values
# 2007 has 87 NaN values
# 2008 has 76 NaN values
# 2009 has 78 NaN values
# 2010 has 74 NaN values
# 2011 has 79 NaN values
# 2012 has 88 NaN values
# 2013 has 88 NaN values
# 2014 has 136 NaN values
# 2015 has 171 NaN values
# 2016 has 199 NaN values
# Unnamed: 61 has 199 NaN values

# %%
import os

def clean_csv(dir_name):
    RAW_DATA_PATH = os.path.join('data', 'raw_data', dir_name)
    filenames = os.listdir(RAW_DATA_PATH)
    RAW_FILE_PATH = filenames[0]
    
    df = pd.read_csv(os.path.join(RAW_DATA_PATH, RAW_FILE_PATH), header=2)
    delete_rows(df, to_remove)
    df.drop(['Country Code', 'Indicator Name', 'Indicator Code', '2015', '2016', 'Unnamed: 61'], axis=1, inplace=True)
    df.drop([str(x) for x in range(1960, 1995)], axis=1, inplace=True)
    df.rename(columns={'Country Name':'country_name'}, inplace=True)
    
    CLEAN_DATA_PATH = os.path.join('data', 'clean_data', dir_name, )
    df.to_csv(CLEAN_DATA_PATH + '.csv', index=False)
    
dir_names = ['education_expenditure', 'gdp', 'health_expenditure', 'infant_mortality', 
             'life_expectancy', 'military_expenditure', 'net_aid']

for dir_name in dir_names:
    if not os.path.exists('data/clean_data/' + dir_name + '.csv'):
        clean_csv(dir_name)
    else:
        print(dir_name + '.csv already exists.')
# Out:
# education_expenditure.csv already exists.
# gdp.csv already exists.
# health_expenditure.csv already exists.
# infant_mortality.csv already exists.
# life_expectancy.csv already exists.
# military_expenditure.csv already exists.
# net_aid.csv already exists.

# %%
def read_my_csv(filename):
    DATA_PATH = os.path.join('data', 'clean_data', filename)
    return pd.read_csv(DATA_PATH, index_col='country_name')

educ_exp = read_my_csv('education_expenditure.csv')
gdp = read_my_csv('gdp.csv')
health_exp = read_my_csv('health_expenditure.csv')
inf_mort = read_my_csv('infant_mortality.csv')
life_exp = read_my_csv('life_expectancy.csv')
mili_exp = read_my_csv('military_expenditure.csv')
net_aid = read_my_csv('net_aid.csv')

all_df = [educ_exp, gdp, health_exp, inf_mort, life_exp, mili_exp, net_aid]
all_df_names = ['educ_exp', 'gdp', 'health_exp', 'inf_mort', 'life_exp', 'mili_exp', 'net_aid']

# %%
for df in all_df:
    df.fillna(method='ffill', axis=1, inplace=True)
    df.fillna(method='bfill', axis=1, inplace=True)

# %%
for df, name in zip(all_df, dir_names):
    print(sum(df.isnull().any(axis=1)), 'rows of missing values in', name)
# Out:
# 14 rows of missing values in education_expenditure
# 3 rows of missing values in gdp
# 9 rows of missing values in health_expenditure
# 7 rows of missing values in infant_mortality
# 4 rows of missing values in life_expectancy
# 33 rows of missing values in military_expenditure
# 29 rows of missing values in net_aid

# %%
net_aid[net_aid.isnull().any(axis=1)].index
# Out:
# Index(['Andorra', 'Australia', 'Austria', 'Belgium', 'Canada', 'Switzerland',
#        'Curacao', 'Germany', 'Denmark', 'Spain', 'Finland', 'France',
#        'United Kingdom', 'Greece', 'Ireland', 'Iceland', 'Italy', 'Japan',
#        'Liechtenstein', 'Luxembourg', 'Monaco', 'Netherlands', 'Norway',
#        'New Zealand', 'Portugal', 'San Marino', 'Sweden',
#        'Sint Maarten (Dutch part)', 'United States'],
#       dtype='object', name='country_name')

# %%
all_df.pop(6)
all_df_names.remove('net_aid')

countries_to_drop = [x for x in mili_exp[mili_exp.isnull().any(axis=1)].index]
for df in all_df:
    df.drop(countries_to_drop, axis=0, inplace=True)

# %%
dir_names.remove('net_aid')
for df, name in zip(all_df, dir_names):
    print(sum(df.isnull().any(axis=1)), 'rows of missing values in', name)
# Out:
# 9 rows of missing values in education_expenditure
# 0 rows of missing values in gdp
# 2 rows of missing values in health_expenditure
# 1 rows of missing values in infant_mortality
# 0 rows of missing values in life_expectancy
# 0 rows of missing values in military_expenditure

# %%
educ_exp[educ_exp.isnull().any(axis=1)].index
# Out:
# Index(['Bosnia and Herzegovina', 'Haiti', 'Iraq', 'Montenegro', 'Nigeria',
#        'Papua New Guinea', 'Somalia', 'Uzbekistan', 'Kosovo'],
#       dtype='object', name='country_name')

# %%
for df in all_df:
    for column in df.columns:
        df.loc[:, column].fillna(np.nanmedian(df.loc[:, column]), inplace=True)

# %%
for df, name in zip(all_df, dir_names):
    print(sum(df.isnull().any(axis=1)), 'rows of missing values in', name)
# Out:
# 0 rows of missing values in education_expenditure
# 0 rows of missing values in gdp
# 0 rows of missing values in health_expenditure
# 0 rows of missing values in infant_mortality
# 0 rows of missing values in life_expectancy
# 0 rows of missing values in military_expenditure

# %%
educ_exp
# Out:
#                               1995      1996      1997      1998      1999  \
# country_name
# Afghanistan                3.46196   3.46196   3.46196   3.46196   3.46196
# Angola                     2.59149   2.59149   2.59149   2.59149   2.59149
# Albania                    3.76471   2.97630   3.23428   3.32642   3.37971
# United Arab Emirates       1.10944   1.10944   1.10944   1.10944   1.10944
# Argentina                  3.73198   3.73198   3.73198   4.03987   4.52168
# Armenia                    1.84843   1.84843   1.84843   1.84843   2.23519
# Australia                  5.13367   5.23053   5.23053   5.23053   5.23053
# Austria                    5.44146   5.27168   5.27168   6.11990   6.12533
# Azerbaijan                 3.33737   3.51252   3.51252   3.38000   4.21217
# Burundi                    5.01511   4.08324   4.08324   4.08324   3.41745
# Belgium                    2.97274   3.02611   3.02611   3.02611   3.02611
# Benin                      2.74789   2.74789   2.74789   2.74789   2.62665
# Burkina Faso               1.44026   1.44026   1.44026   1.44026   1.44026
# Bangladesh                 1.95247   1.95247   1.95247   1.95247   2.13282
# Bulgaria                   3.44701   2.71204   2.71204   2.81427   2.81427
# Bahrain                    2.87436   2.87436   2.87436   2.87436   2.87436
# Bosnia and Herzegovina     3.81086   3.83658   3.84718   3.84718   4.09433
# Belarus                    6.00001   6.00001   6.00001   6.00001   6.00001
# Belize                     5.44344   5.44344   5.44344   5.44344   5.44344
# Bolivia                    5.60817   4.65741   4.65741   5.52301   5.65932
# Brazil                     4.47317   4.47317   4.47317   4.75666   3.80062
# Brunei Darussalam          5.25395   5.25395   5.25395   5.25395   4.93205
# Botswana                  10.67859  10.67859  10.67859  10.67859  10.67859
# Central African Republic   1.69002   1.69002   1.69002   1.69002   1.69002
# Canada                     6.32445   6.32445   6.32445   5.51196   5.54994
# Switzerland                5.07213   5.07918   5.07918   4.88814   4.89071
# Chile                      2.64011   2.88004   3.09043   3.43289   3.84052
# China                      1.84825   1.85964   1.85964   1.85111   1.89593
# Cote d'Ivoire              4.30145   4.05623   4.03089   3.78794   4.09433
# Cameroon                   1.93258   1.93258   1.93258   1.93258   1.93258
# ...                            ...       ...       ...       ...       ...
# Serbia                     4.51091   4.51091   4.51091   4.51091   4.51091
# South Sudan                0.80521   0.80521   0.80521   0.80521   0.80521
# Slovak Republic            4.31547   4.13969   4.12916   4.12916   4.11247
# Slovenia                   4.92384   4.92384   4.92384   4.92384   4.92384
# Sweden                     6.22390   6.92501   6.92501   7.16734   6.93026
# Swaziland                  5.65314   4.93816   4.93816   4.93816   5.09095
# Seychelles                 4.77012  3.60644  3.60644  3.60644  3.60644
# Syrian Arab Republic       5.13014  5.13014  5.13014  5.13014  5.13014
# Chad                       1.98194  2.25790  2.20615  2.85071  2.85071
# Togo                       4.42320  4.43707  4.72764  4.68305  4.87673
# Thailand                   3.51031  4.80828  4.53977  4.12839  4.12839
# Tajikistan                 4.00675  3.93511  4.01803  4.01803  4.01803
# Turkmenistan               3.04925  3.04925  3.04925  3.04925  3.04925
# Timor-Leste               10.48715  9.33840  6.41859  5.99594  7.93279
# Trinidad and Tobago        3.13660  3.13660  3.13660  3.13660  3.13660
# Tunisia                    6.25481  6.25481  6.25036  6.25036  6.25036
# Turkey                     2.86247  2.86247  4.07056  4.77450  4.77450
# Tanzania                   4.62239  4.62239  4.62239  4.62239  3.48143
# Uganda                     1.96590  1.96765  1.87724  1.49607  1.70442
# Ukraine                    7.31088  6.16237  6.69233  6.74435  5.95064
# Uruguay                    2.88026  4.35527  4.35527  4.35527  4.35527
# United States              5.42001  5.22390  5.19486  4.94379  4.94379
# Uzbekistan                 4.33702  4.28408  4.38531  4.53051  4.49753
# Venezuela, RB              6.87468  6.87468  6.87468  6.87468  6.87468
# Vietnam                    5.13722  4.81372  5.53329  5.65200  5.65200
# Kosovo                     4.33702  4.28408  4.38531  4.53051  4.49753
# Yemen, Rep.                4.56060  4.56060  4.56060  4.56060  4.56060
# South Africa               5.72174  5.96275  6.36892  5.99752  6.05629
# Zambia                     1.09972  1.09972  1.09972  1.09972  1.09972
# Zimbabwe                   1.97333  1.97333  8.38322  8.48536  8.42933
#
# [166 rows x 20 columns]

# %%
for i, val_name in zip(range(len(all_df)), all_df_names):
    df = all_df[i]
    df.reset_index(inplace=True)
    df = df.melt(id_vars='country_name', var_name='year', value_name=val_name)
    df['country_name_year'] = df['country_name'].map(str) + df['year'].map(str)
    df.drop(['country_name', 'year'], axis=1, inplace=True)
    df.set_index('country_name_year', inplace=True)
    all_df[i] = df

# %%
master_df = all_df[0].join([x for x in all_df[1:]])
master_df = master_df[['educ_exp', 'gdp', 'health_exp', 'mili_exp', 'inf_mort', 'life_exp']]

# %%
master_df.head()
# Out:
#                           educ_exp           gdp  health_exp  mili_exp  \
# country_name_year
# Afghanistan1995            3.46196    119.899019    7.094141  2.369786
# Angola1995                 2.59149    386.389752   72.135102  4.707393
# Albania1995                3.76471    760.559376   25.966105  2.099713
# United Arab Emirates1995   1.10944  27973.742816   78.969429  4.231250
# Argentina1995              3.73198   7373.427403   59.757519  1.473075
#
#                           inf_mort   life_exp
# country_name_year
# Afghanistan1995              105.0  53.139390
# Angola1995                   132.8  42.051463
# Albania1995                   29.1  72.236024
# United Arab Emirates1995      11.2  73.115073
# Argentina1995                 20.8  72.665122

# %% [markdown]
# # Linear Regression

# %% [markdown]
# # Single Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

X = master_df.loc[:, 'educ_exp':'mili_exp']
y = master_df.loc[:, 'life_exp']

tree_reg = DecisionTreeRegressor(max_depth)

# %% [markdown]
# # Random Forest
